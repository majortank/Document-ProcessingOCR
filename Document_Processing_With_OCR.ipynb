# %% [markdown]
# <a href="https://colab.research.google.com/github/majortank/Document-ProcessingOCR/blob/main/Document_Processing_With_OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Document Processing With OCR

# %%
pip install pillow pytesseract langchain langchain-core langchain-openai openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 3.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 1. Install and Import Libraries

# %%
from PIL import Image
import pytesseract

from langchain_openai import ChatOpenAI
from langgraph.prebuilt import create_react_agent
from langchain.tools import tool

# %% [markdown]
# ## 2. Create ORC Tool

# %%
# -----------------------------
# Define OCR tool
# -----------------------------
@tool
def ocr_read_document(image_path: str) -> str:
    """Reads an image from the given path and returns extracted text using OCR."""
    try:
        text = pytesseract.image_to_string(Image.open(image_path))
        return text
    except Exception as e:
        return f"Error reading image: {e}"

# %% [markdown]
# ### 2.1 Use OCR to Parse a Sample Document

# %%
from IPython.display import display
image_path = 'OCR/g_invoice.png'
img = Image.open(image_path)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=694x898>

# %%
ocr_text = ocr_read_document.run("OCR/g_invoice.png")
print("Raw OCR Output:\n----------------\n", ocr_text)
# Out:
# Raw OCR Output:
# ----------------
#
#
#
#
# Company Name INVOICE
#
#
#
#
#
#
#
#
#
# [Street Address]
# [city, ST ZF] pare [42/9/2019
# hone: [000-000-0000] Invoice # | (123456)
# Fax: [000-000-0000] ‘CUSTOMER ID 1123]
# Website: somedomain.com ue pare [7478/2020
#
#
#
#
#
#
#
# [Name]
# {Company Name]
# [Street Address]
# [City, ST ZIP]
# [Phone]
#
# ne
#
#
#
# [Service Fee] 730.00
# [Labor: § hours at $75/hr] 375.00
# [Parts] x 345.00,
#
#
#
# 1, Total payment due in 30 days,
# 2. Please include the invoice number on your check
#
#
#
#
#
# Make all checks payatie to
# [Your Company Name]
#
#
#
#
#
# It you have any questions about this invoice, please contact
# Name, Phone #, E-mail]
# Thank You For Your Business!
#
# ps: eww vertexe2.comfExcerTemplates/excehinvoice-templte html Involoe Template © 2010-2019 by Vertxt2.com
